# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from keras.layers import Dropout
import operator
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
no_of_words = 9000

# %%
data = pd.read_csv('spam.csv' , encoding='latin-1')
data = np.array(data)
x = data[:,1:2]
y = data[:,0:1]

for i in range(len(y)):
    if y[i][0] == 'ham' :
        y[i][0] = 0
    else:
        y[i][0] = 1


para = ''
for i in range(len(x)):
    para += x[i][0].strip() + ' '

para = para.replace('.','').replace('?','').replace("'",'').replace(',','').replace('-','').replace('+','').replace('!','')
para = para.replace('*','').replace('/','').replace('~','').replace(':','').replace(')','').replace('()','').replace('#','')

all_worlds = para.lower().split(' ')
dictionary = {}
for item in all_worlds:
    if item in dictionary:
        dictionary[item] += 1
    else:
        dictionary[item] = 1
dictionary
sorted_dictionary = sorted(dictionary.items(), key=operator.itemgetter(1))
sorted_dictionary = sorted_dictionary[::-1]

tempList = []
for i in range(len(sorted_dictionary)):
    if len(sorted_dictionary[i][0]) >= 1 and "&" not in sorted_dictionary[i][0]:
        tempList.append(sorted_dictionary[i])
tempList = tempList[0:no_of_words]
len(tempList)

final_input = np.atleast_2d()
for i in range(len(x)) :
    tempData = []
    str =x[i][0].replace('.','').replace('?','').replace("'",'').replace(',','').replace('-','').replace('+','').replace('!','').replace('&','')
    str = str.replace('*','').replace('/','').replace('~','').replace(':','').replace(')','').replace('()','').replace('#','')
    for j in range(len(tempList)) :
        if tempList[j][0] not in str :
            tempData.append(0)
        else :
            tempData.append(1)
    final_input.append(tempData)
    
final_input = np.array(final_input)
final_input.shape
# Out:
# (5572, 9000)

# %%
x_train,x_test,y_train,y_test = train_test_split(final_input,y,test_size=0.1 , random_state=0)
x_temp_test = x_test
y_temp_test = y_test
y_train.shape
# Out:
# (5014, 1)

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)
# Out:
# C:\Users\VasuPC\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int32 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
classifier = Sequential()

classifier.add(Dense(units=50,activation='relu',kernel_initializer='uniform',input_dim=no_of_words))
classifier.add(Dropout(rate=0.5))
classifier.add(Dense(units=25,activation='relu',kernel_initializer='uniform'))
classifier.add(Dropout(rate=0.5))
classifier.add(Dense(units=10,activation='relu',kernel_initializer='uniform'))
classifier.add(Dropout(rate=0.5))
classifier.add(Dense(units=1,activation='sigmoid',kernel_initializer='uniform'))

#opt = optimizers.SGD(lr=0.01)
classifier.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam')

classifier.fit(x_train,y_train,batch_size=128,epochs=100)
# Out:
# Epoch 1/100
# 5014/5014 [==============================] - 2s 416us/step - loss: 0.6112 - acc: 0.8566
# Epoch 2/100
# 5014/5014 [==============================] - 1s 272us/step - loss: 0.2201 - acc: 0.8696
# Epoch 3/100
# 5014/5014 [==============================] - 1s 259us/step - loss: 0.1571 - acc: 0.8696
# Epoch 4/100
# 5014/5014 [==============================] - 1s 264us/step - loss: 0.1272 - acc: 0.8696
# Epoch 5/100
# 5014/5014 [==============================] - 1s 255us/step - loss: 0.1156 - acc: 0.8696
# Epoch 6/100
# 5014/5014 [==============================] - 2s 303us/step - loss: 0.1099 - acc: 0.9160
# Epoch 7/100
# Epoch 92/100
# 5014/5014 [==============================] - 1s 280us/step - loss: 0.0187 - acc: 0.9956
# Epoch 93/100
# 5014/5014 [==============================] - 1s 269us/step - loss: 0.0191 - acc: 0.9948
# Epoch 94/100
# 5014/5014 [==============================] - 1s 282us/step - loss: 0.0159 - acc: 0.9962
# Epoch 95/100
# 5014/5014 [==============================] - 1s 259us/step - loss: 0.0160 - acc: 0.9958
# Epoch 96/100
# 5014/5014 [==============================] - 1s 269us/step - loss: 0.0166 - acc: 0.9966
# Epoch 97/100
# 5014/5014 [==============================] - 1s 268us/step - loss: 0.0182 - acc: 0.9956
# Epoch 98/100
# 5014/5014 [==============================] - 1s 261us/step - loss: 0.0159 - acc: 0.9974
# Epoch 99/100
# 5014/5014 [==============================] - 1s 262us/step - loss: 0.0180 - acc: 0.9958
# Epoch 100/100
# 5014/5014 [==============================] - 1s 261us/step - loss: 0.0158 - acc: 0.9980

# %%
y_pred = classifier.predict(x_test)
y_pred
# Out:
# array([[  5.77893448e-22],
#        [  3.20521565e-08],
#        [  2.64208470e-24],
#        [  0.00000000e+00],
#        [  1.59054034e-10],
#        [  7.73545639e-15],
#        [  1.14672793e-09],
#        [  2.00677691e-14],
#        [  3.23668536e-10],
#        [  9.98939574e-01],
#        [  1.32247908e-06],
#        [  5.36626871e-17],
#        [  1.28097818e-14],
#        [  9.98939574e-01],
#        [  6.17025280e-16],
#        [  9.02560711e-01],
#        [  9.98939574e-01],
#        [  6.20760664e-04],
#        [  4.20070090e-11],
#        [  1.33100383e-17],
#        [  4.06199336e-12],
#        [  1.89775203e-24],
#        [  3.73761135e-12],
#        [  4.06311017e-07],
#        [  9.98891413e-01],
#        [  4.55760496e-09],
#        [  9.98693168e-01],
#        [  3.28196766e-05],
#        [  9.98939574e-01],
#        [  5.10844529e-06],
#        [  7.70692375e-13],
#        [  9.98939574e-01],
#        [  5.24475796e-10],
#        [  0.00000000e+00],
#        [  9.98939574e-01],
#        [  3.84416489e-06],
#        [  4.83517108e-22],
#        [  2.21052935e-04],
#        [  1.01246445e-09],
#        [  9.98939574e-01],
#        [  8.26119795e-09],
#        [  1.13922992e-29],
#        [  2.52935596e-27],
#        [  1.26869760e-12],
#        [  2.95851138e-15],
#        [  4.01536013e-34],
#        [  7.99943871e-17],
#        [  1.33343338e-24],
#        [  9.98939574e-01],
#        [  7.86277815e-06],
#        [  1.44866021e-06],
#        [  1.56639421e-15],
#        [  1.47201449e-01],
#        [  1.04766759e-05],
#        [  1.54044812e-08],
#        [  2.17751257e-22],
#        [  6.00447947e-06],
#        [  2.08454320e-09],
#        [  9.98939574e-01],
#        [  5.11775951e-12],
#        [  4.70584249e-12],
#        [  2.75693552e-12],
#        [  9.98939574e-01],
#        [  8.80068727e-03],
#        [  9.98943150e-01],
#        [  2.02996951e-12],
#        [  9.95274420e-14],
#        [  1.07642874e-18],
#        [  9.91983260e-16],
#        [  8.04583988e-38],
#        [  0.00000000e+00],
#        [  2.64707569e-06],
#        [  9.98939574e-01],
#        [  4.12619294e-04],
#        [  5.67600544e-08],
#        [  4.79781770e-11],
#        [  1.04817649e-27],
#        [  3.37974010e-10],
#        [  1.69343033e-30],
#        [  4.67128047e-34],
#        [  0.00000000e+00],
#        [  1.23266372e-18],
#        [  9.98939574e-01],
#        [  1.23098232e-09],
#        [  0.00000000e+00],
#        [  3.71745110e-01],
#        [  3.47748691e-10],
#        [  9.98939574e-01],
#        [  2.27788296e-29],
#        [  5.61732159e-04],
#        [  1.36702374e-01],
#        [  2.88461425e-11],
#        [  3.73295823e-35],
#        [  7.30948768e-09],
#        [  1.62148172e-06],
#        [  1.22441911e-27],
#        [  1.89859966e-05],
#        [  2.99498781e-09],
#        [  1.46761447e-19],
#        [  9.98939574e-01],
#        [  4.14498077e-37],
#        [  5.65979015e-08],
#        [  9.46341561e-10],
#        [  3.57896898e-21],
#        [  6.33777599e-05],
#        [  1.06161363e-18],
#        [  9.98939574e-01],
#        [  7.46421307e-08],
#        [  9.98939574e-01],
#        [  9.98939574e-01],
#        [  9.98939574e-01],
#        [  2.35311047e-18],
#        [  9.98939574e-01],
#        [  9.98939574e-01],
#        [  1.88796601e-26],
#        [  5.50128561e-06],
#        [  7.84013973e-05],
#        [  1.62053098e-07],
#        [  2.02844248e-14],
#        [  2.99498781e-09],
#        [  9.96264507e-24],
#        [  2.02570361e-23],
#        [  1.39396230e-21],
#        [  3.61098785e-15],
#        [  7.17498147e-15],
#        [  9.98939574e-01],
#        [  1.48059506e-16],
#        [  7.90951071e-22],
#        [  1.00805481e-22],
#        [  3.37173188e-13],
#        [  1.52263632e-10],
#        [  1.90555127e-08],
#        [  9.96594398e-18],
#        [  1.76516080e-10],
#        [  0.00000000e+00],
#        [  3.99696024e-19],
#        [  9.98939574e-01],
#        [  1.37112760e-12],
#        [  9.15752535e-05],
#        [  2.93691852e-03],
#        [  1.66298058e-19],
#        [  9.98939574e-01],
#        [  0.00000000e+00],
#        [  4.03356464e-28],
#        [  9.98903155e-01],
#        [  2.38721678e-16],
#        [  1.53989293e-23],
#        [  3.61052167e-04],
#        [  9.98939574e-01],
#        [  8.79512663e-06],
#        [  9.98939574e-01],
#        [  1.34343079e-12],
#        [  4.00375002e-12],
#        [  1.05712217e-10],
#        [  2.39640366e-13],
#        [  5.80517351e-14],
#        [  7.30948768e-09],
#        [  2.50644818e-27],
#        [  2.54791075e-27],
#        [  7.77547294e-18],
#        [  0.00000000e+00],
#        [  7.38913097e-10],
#        [  9.98934090e-01],
#        [  8.36002246e-18],
#        [  3.81098059e-03],
#        [  1.21163623e-02],
#        [  1.02952392e-04],
#        [  3.12695398e-32],
#        [  6.09140334e-05],
#        [  9.98939574e-01],
#        [  1.78683859e-08],
#        [  8.92344231e-24],
#        [  5.75732084e-09],
#        [  1.61879173e-11],
#        [  5.41358408e-15],
#        [  9.98939574e-01],
#        [  1.20975361e-18],
#        [  2.23046776e-12],
#        [  0.00000000e+00],
#        [  1.39695357e-29],
#        [  0.00000000e+00],
#        [  1.92334909e-07],
#        [  4.04176082e-27],
#        [  1.30668472e-17],
#        [  6.18470440e-05],
#        [  3.38644945e-11],
#        [  4.98594891e-05],
#        [  9.98827517e-01],
#        [  1.55813305e-03],
#        [  5.43713783e-22],
#        [  9.98939574e-01],
#        [  9.98939574e-01],
#        [  0.00000000e+00],
#        [  1.81200357e-05],
#        [  1.26121918e-37],
#        [  2.97631575e-16],
#        [  9.98715520e-01],
#        [  1.12275487e-08],
#        [  9.13495555e-08],
#        [  7.19539548e-06],
#        [  2.04860070e-27],
#        [  6.66636568e-09],
#        [  6.08818298e-17],
#        [  9.98939574e-01],
#        [  9.98965740e-01],
#        [  9.33835719e-16],
#        [  0.00000000e+00],
#        [  1.95325015e-07],
#        [  1.17242341e-15],
#        [  3.78053366e-10],
#        [  5.34137079e-14],
#        [  1.28203400e-14],
#        [  9.98939574e-01],
#        [  6.68775988e-17],
#        [  1.90387149e-17],
#        [  2.82717406e-27],
#        [  9.84116213e-18],
#        [  2.60991929e-24],
#        [  2.05857890e-14],
#        [  1.22001610e-11],
#        [  9.98677909e-01],
#        [  9.98993337e-01],
#        [  2.23969182e-04],
#        [  5.97058167e-11],
#        [  2.26820157e-33],
#        [  3.88372506e-18],
#        [  9.03766195e-23],
#        [  9.98939574e-01],
#        [  9.81154621e-01],
#        [  1.60564596e-07],
#        [  7.00241129e-04],
#        [  2.00508890e-26],
#        [  9.98939574e-01],
#        [  0.00000000e+00],
#        [  0.00000000e+00],
#        [  2.33000249e-01],
#        [  3.04549443e-14],
#        [  1.89779641e-08],
#        [  2.84371526e-10],
#        [  2.68436315e-12]], dtype=float32)

# %%
rnd = np.random.randint(0,len(y_test))
print('Actual output :' , y_test[rnd][0])
print('Predicted Output output :' , round(y_pred[rnd][0]))
# Out:
# Actual output : 0
# Predicted Output output : 0.0

# %%
y_pred = (y_pred > 0.5)
y_test = y_test.astype(int)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[461,   4],
#        [  7,  86]], dtype=int64)

# %%
def ConvertText(text):
    tempData = []

    str = text.replace('.', '').replace('?', '').replace("'", '').replace(',', '').replace('-', '').replace('+','').replace('!', '').replace('&', '')
    str = str.replace('*', '').replace('/', '').replace('~', '').replace(':', '').replace(')', '').replace('()','').replace('#', '')
    for j in range(len(tempList)):
        if tempList[j][0] not in text:
            tempData.append(0)
        else:
            tempData.append(1)
    return tempData

# %%
converted_text = ConvertText("Hurray ! you won a lottery of cash prize 50000")
#converted_text = ConvertText("I am fine ! Thankyou!")
converted_text = np.array([converted_text])
converted_text.shape
y_pred_single = classifier.predict(converted_text)

if y_pred_single[0][0] > 0.5 :
    print('There is', round(y_pred_single[0][0]*100,2) ,'% chance that it is a SPAM')
else :
    print('There is', round((1-y_pred_single[0][0])*100,2) ,'% chance that it is NOT a SPAM')
# Out:
# There is 99.87 % chance that it is a SPAM
